# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\Lenovo\1代码_PSG课题\代码上传\data\figure 3.xlsx',
                  index_col = [0])

# %%
item_list = ['freqs', 'pg_max', 'pg_min', 'pg_mean',
                  'sr_max', 'sr_min', 'sr_mean',
                  'bg_max', 'bg_min', 'bg_mean',
                  'sr_max', 'sr_min', 'sr_mean',
                  'sg_max', 'sg_min', 'sg_mean',
                  'sr_max', 'sr_min', 'sr_mean']
for i in item_list:
    locals()[i] = df[i].tolist()

# %%
fig, ax = plt.subplots(figsize=(4,4))
line1, = ax.plot(freqs, sr_mean, color = 'gray')
ax.plot(freqs, sr_min, color = 'gray', alpha=0.1)
ax.plot(freqs, sr_max, color = 'gray' ,alpha=0.1)
ax.fill_between(freqs, sr_min, sr_max, color = 'gray',alpha=0.3)
line2, = ax.plot(freqs, pg_mean, color = 'red')
ax.plot(freqs, pg_min, color = 'gray',alpha=0.1)
ax.plot(freqs, pg_max, color = 'gray' ,alpha=0.1)
ax.fill_between(freqs, pg_min, pg_max, color = 'red',alpha=0.3)
ax.legend([line2,line1], ['Wake', 'Surrogate'], fancybox = True, prop={'size': 15} )
ax.set_ylim([0, 0.095])
ax.set_xticks([0,10, 20, 30, 40,50]) 
ax.set_xticklabels([0,10, 20, 30, 40,50],fontsize = 15)
ax.set_xlabel ('Frequency (Hz)',fontsize = 15)
ax.set_yticks([ 0.01, 0.03, 0.05,0.07, 0.09,]) 
ax.set_yticklabels([ 0.01, 0.03, 0.05,0.07, 0.09,],fontsize = 15)
ax.set_ylabel ('Coherence',fontsize = 15)
plt.vlines(x=3,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=7,ymin = 0.005, ymax = 0.09,color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=13,ymin = 0.005, ymax = 0.09,color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=20,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=30,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4,4))
line1, = ax.plot(freqs, sr_mean, color = 'gray')
ax.plot(freqs, sr_min, color = 'gray', alpha=0.1)
ax.plot(freqs, sr_max, color = 'gray' ,alpha=0.1)
ax.fill_between(freqs, sr_min, sr_max, color = 'gray',alpha=0.3)
line2, = ax.plot(freqs, bg_mean, color = 'blue')
ax.plot(freqs, bg_min, color = 'gray',alpha=0.1)
ax.plot(freqs, bg_max, color = 'gray' ,alpha=0.1)
ax.fill_between(freqs, bg_min, bg_max, color = 'blue',alpha=0.3)
ax.legend([line2, line1], ['NREM','Surrogate'], fancybox = True, prop={'size': 15})
ax.set_ylim([0, 0.095])
ax.set_xticks([0,10, 20, 30, 40,50]) 
ax.set_xticklabels([0,10, 20, 30, 40,50],fontsize = 15)
ax.set_xlabel ('Frequency (Hz)',fontsize = 15)
ax.set_yticks([ 0.01, 0.03, 0.05,0.07, 0.09,]) 
ax.set_yticklabels([ 0.01, 0.03, 0.05,0.07, 0.09,],fontsize = 15)
ax.set_ylabel ('Coherence',fontsize = 15)
plt.vlines(x=3,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=7,ymin = 0.005, ymax = 0.09,color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=13,ymin = 0.005, ymax = 0.09,color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=20,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=30,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4,4))
line1, = ax.plot(freqs, sr_mean, color = 'gray')
ax.plot(freqs, sr_min, color = 'gray', alpha=0.1)
ax.plot(freqs, sr_max, color = 'gray' ,alpha=0.1)
ax.fill_between(freqs, sr_min, sr_max, color = 'gray',alpha=0.3)
line2, = ax.plot(freqs, sg_mean, color = 'orange')
ax.plot(freqs, sg_min, color = 'gray',alpha=0.1)
ax.plot(freqs, sg_max, color = 'gray' ,alpha=0.1)
ax.fill_between(freqs, sg_min, sg_max, color = 'orange',alpha=0.3)
ax.legend([line2, line1], ['REM', 'Surrogate'], fancybox = True, prop={'size': 15})
ax.set_ylim([0, 0.095])
ax.set_xticks([0,10, 20, 30, 40,50]) 
ax.set_xticklabels([0,10, 20, 30, 40,50],fontsize = 15)
ax.set_xlabel ('Frequency (Hz)',fontsize = 15)
ax.set_yticks([ 0.01, 0.03, 0.05,0.07, 0.09,]) 
ax.set_yticklabels([ 0.01, 0.03, 0.05,0.07, 0.09,],fontsize = 15)
ax.set_ylabel ('Coherence',fontsize = 15)
plt.vlines(x=3,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=7,ymin = 0.005, ymax = 0.09,color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=13,ymin = 0.005, ymax = 0.09,color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=20,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.vlines(x=30,ymin = 0.005, ymax = 0.09, color='gray', alpha=0.5, linestyle='--')
plt.tight_layout()
